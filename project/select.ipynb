# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data/spider.csv")

# %%
my_data = data.iloc[6400:,:]
my_data
# Out:
#       Unnamed: 0                   db_id  \
# 6400        6400    cre_Docs_and_Epenses
# 6401        6401    cre_Docs_and_Epenses
# 6402        6402    cre_Docs_and_Epenses
# 6403        6403    cre_Docs_and_Epenses
# 6404        6404    cre_Docs_and_Epenses
# ...          ...                     ...
# 8029        8029                  singer
# 8030        8030  real_estate_properties
# 8031        8031  real_estate_properties
# 8032        8032  real_estate_properties
# 8033        8033  real_estate_properties
#
#                                                   query  \
# 6400                     SELECT count(*) FROM Documents
# 6401  SELECT document_type_code ,  document_name ,  ...
# 6402  SELECT document_type_code ,  document_name ,  ...
# 6403  SELECT document_id ,  document_name FROM Docum...
# 6404  SELECT document_id ,  document_name FROM Docum...
# ...                                                 ...
# 8029  SELECT Citizenship FROM singer WHERE Birth_Yea...
# ...

# %%
my_data["HAVING"].plot()
# Out:
# <Axes: >

# %%
my_data["JOIN"].plot()
# Out:
# <Axes: >

# %%
my_data["GROUP BY"].plot()
# Out:
# <Axes: >

# %%
my_data["ORDER BY"].plot()
# Out:
# <Axes: >

# %%
my_data.loc[:,'Total'] = my_data[["HAVING", "JOIN", "GROUP BY", "ORDER BY"]].copy().sum(axis=1)
my_data
# Out:
#       Unnamed: 0                   db_id  \
# 6400        6400    cre_Docs_and_Epenses
# 6401        6401    cre_Docs_and_Epenses
# 6402        6402    cre_Docs_and_Epenses
# 6403        6403    cre_Docs_and_Epenses
# 6404        6404    cre_Docs_and_Epenses
# ...          ...                     ...
# 8029        8029                  singer
# 8030        8030  real_estate_properties
# 8031        8031  real_estate_properties
# 8032        8032  real_estate_properties
# 8033        8033  real_estate_properties
#
#                                                   query  \
# 6400                     SELECT count(*) FROM Documents
# 6401  SELECT document_type_code ,  document_name ,  ...
# 6402  SELECT document_type_code ,  document_name ,  ...
# 6403  SELECT document_id ,  document_name FROM Docum...
# 6404  SELECT document_id ,  document_name FROM Docum...
# ...                                                 ...
# 8029  SELECT Citizenship FROM singer WHERE Birth_Yea...
# ...

# %%
my_data.sort_values(by=['Total'], ascending=False, inplace=True)
my_data
# Out:
# /var/folders/__/4fkccwzn4898x6sm4zh8dkth0000gn/T/ipykernel_23405/3700208911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_data.sort_values(by=['Total'], ascending=False, inplace=True)
#       Unnamed: 0                   db_id  \
# 7176        7176                   car_1
# 7175        7175                   car_1
# 6955        6955            architecture
# 7178        7178                   car_1
# 6941        6941         tracking_orders
# ...          ...                     ...
# 7199        7199                flight_2
# 7200        7200                flight_2
# 7201        7201                flight_2
# 7202        7202                flight_2
# 8033        8033  real_estate_properties
#
#                                                   query  \
# ...

# %%
my_data = my_data.iloc[:50,1:]

# %%
my_data = my_data.sort_index()
my_data = my_data.iloc[:,:-1]
my_data
# Out:
#                 db_id                                              query  \
# 6491      scientist_1  SELECT T3.name FROM assignedto AS T1 JOIN proj...
# 6492      scientist_1  SELECT T3.name FROM assignedto AS T1 JOIN proj...
# 6563           wine_1  SELECT T1.Area FROM APPELLATIONS AS T1 JOIN WI...
# 6564           wine_1  SELECT T1.Area FROM APPELLATIONS AS T1 JOIN WI...
# 6565           wine_1  SELECT T1.Color FROM GRAPES AS T1 JOIN WINE AS...
# 6566           wine_1  SELECT T1.Color FROM GRAPES AS T1 JOIN WINE AS...
# 6581           wine_1  SELECT T1.County FROM APPELLATIONS AS T1 JOIN ...
# 6582           wine_1  SELECT T1.County FROM APPELLATIONS AS T1 JOIN ...
# 6587           wine_1  SELECT T2.Winery FROM GRAPES AS T1 JOIN WINE A...
# 6588           wine_1  SELECT T2.Winery FROM GRAPES AS T1 JOIN WINE A...
# 6619    train_station  SELECT T2.name FROM train_station AS T1 JOIN s...
# 6689   driving_school  SELECT T2.city FROM Customers AS T1 JOIN Addre...
# ...

# %%
my_data.to_csv("data/spider_6400_8034.csv")
